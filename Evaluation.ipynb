# %%
pip install neo4j
# Out:
# Requirement already satisfied: neo4j in c:\users\wendychuaxingzhao\anaconda3\lib\site-packages (5.20.0)
# Requirement already satisfied: pytz in c:\users\wendychuaxingzhao\anaconda3\lib\site-packages (from neo4j) (2022.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase

# Neo4j connection
url = "neo4j+s://e1557b9c.databases.neo4j.io"
username = "neo4j"
password = "m8CFT88LsU8EZ9BzYC4dC0c7Pwgc1ZBQxHKqQKpA3HY"

# Initialize the driver
driver = GraphDatabase.driver(url, auth=(username, password))

def get_neo4j_stats(driver):
    with driver.session() as session:
        # Number of nodes
        num_nodes = session.run("MATCH (n) RETURN count(n) AS num_nodes").single()["num_nodes"]
        
        # Number of relationships
        num_rels = session.run("MATCH ()-[r]->() RETURN count(r) AS num_rels").single()["num_rels"]
        
        # Number of property keys
        num_prop_keys = session.run("CALL db.propertyKeys()").value()
        num_prop_keys = len(num_prop_keys)
        
        # Number of classes (distinct labels)
        num_classes = session.run("CALL db.labels()").value()
        num_classes = len(num_classes)
        
        # Number of RDF triples (considering a triple as a relationship with properties)
        num_rdf_triples = session.run("MATCH (s)-[p]->(o) RETURN count(p) AS num_rdf_triples").single()["num_rdf_triples"]
        
        # Number of instances (distinct nodes with distinct labels)
        num_instances = session.run("MATCH (n) RETURN count(distinct n) AS num_instances").single()["num_instances"]
        
        # Calculate additional metrics
        instantiated_class_ratio = num_instances / num_classes if num_classes != 0 else 0
        instantiated_property_ratio = num_instances / num_prop_keys if num_prop_keys != 0 else 0

        # Class instantiation: Number of instances per class
        class_instantiation = session.run("""
            MATCH (n)
            RETURN labels(n) AS label, count(n) AS count
        """).data()

        # Inverse multiple inheritance: Number of classes with more than one parent class
        inverse_multiple_inheritance = session.run("""
            MATCH (c:Class)-[:SUBCLASS_OF]->(p:Class)
            WITH c, count(p) AS num_parents
            WHERE num_parents > 1
            RETURN count(c) AS inverse_multiple_inheritance
        """).single()["inverse_multiple_inheritance"]
        
        # Subclass property acquisition: Number of properties inherited by subclasses
        subclass_property_acquisition = session.run("""
            MATCH (c:Class)-[:SUBCLASS_OF]->(p:Class)
            MATCH (p)-[:HAS_PROPERTY]->(prop)
            RETURN count(prop) AS subclass_property_acquisition
        """).single()["subclass_property_acquisition"]
        
        # Subclass property instantiation: Number of properties instantiated by subclasses
        subclass_property_instantiation = session.run("""
            MATCH (s:Subclass)-[:HAS_PROPERTY]->(prop)
            RETURN count(prop) AS subclass_property_instantiation
        """).single()["subclass_property_instantiation"]

        return {
            "num_nodes": num_nodes,
            "num_rels": num_rels,
            "num_prop_keys": num_prop_keys,
            "num_classes": num_classes,
            "num_rdf_triples": num_rdf_triples,
            "num_instances": num_instances,
            "instantiated_class_ratio": instantiated_class_ratio,
            "instantiated_property_ratio": instantiated_property_ratio,
            "class_instantiation": class_instantiation,
            "inverse_multiple_inheritance": inverse_multiple_inheritance,
            "subclass_property_acquisition": subclass_property_acquisition,
            "subclass_property_instantiation": subclass_property_instantiation
        }

# Get Neo4j statistics
neo4j_stats = get_neo4j_stats(driver)

# Print the statistics
print(f"Number of nodes: {neo4j_stats['num_nodes']}")
print(f"Number of relationships: {neo4j_stats['num_rels']}")
print(f"Number of property keys: {neo4j_stats['num_prop_keys']}")
print(f"Number of classes: {neo4j_stats['num_classes']}")
print(f"Number of RDF triples: {neo4j_stats['num_rdf_triples']}")
print(f"Number of instances: {neo4j_stats['num_instances']}")
print(f"Instantiated class ratio: {neo4j_stats['instantiated_class_ratio']}")
print(f"Instantiated property ratio: {neo4j_stats['instantiated_property_ratio']}")

print("Class instantiation:")
for item in neo4j_stats['class_instantiation']:
    print(f"Label: {item['label'][0]}, Count: {item['count']}")

print(f"Inverse multiple inheritance: {neo4j_stats['inverse_multiple_inheritance']}")
print(f"Subclass property acquisition: {neo4j_stats['subclass_property_acquisition']}")
print(f"Subclass property instantiation: {neo4j_stats['subclass_property_instantiation']}")
# Out:
# Number of nodes: 2241
# Number of relationships: 1587
# Number of property keys: 451
# Number of classes: 192
# Number of RDF triples: 1587
# Number of instances: 2241
# Instantiated class ratio: 11.671875
# Instantiated property ratio: 4.968957871396896
# Class instantiation:
# Label: Entity, Count: 116
# Label: Financial statement, Count: 4
# Label: Section, Count: 77
# Label: Financial term, Count: 115
# Label: Text, Count: 1
# Label: Financialstatement, Count: 10
# Label: Financialmetric, Count: 45
# Label: Financial_term, Count: 333
# Label: Department, Count: 4
# Label: Financial_statement, Count: 9
# Label: Concept, Count: 241
# Label: Financial_metric, Count: 89
# Label: Financial metric, Count: 27
# Label: Date, Count: 13
# Label: Loan category, Count: 1
# Label: Ecl stage, Count: 3
# Label: Financial product, Count: 1
# Label: Subsidiary, Count: 19
# Label: Debt_security, Count: 3
# Label: Loan, Count: 3
# Label: Document, Count: 1
# Label: Risk category, Count: 4
# Label: Segment, Count: 7
# Label: Geographical location, Count: 4
# Label: Bank, Count: 172
# Label: Person, Count: 98
# Label: Surname, Count: 1
# Label: Building, Count: 8
# Label: Location, Count: 71
# Label: City, Count: 1
# Label: Transportation station, Count: 2
# Label: Public transportation, Count: 1
# Label: Street, Count: 1
# Label: Country house, Count: 1
# Label: Settlement, Count: 1
# Label: Railway station, Count: 1
# Label: Organization, Count: 108
# Label: Financialterm, Count: 15
# Label: Sector, Count: 10
# Label: Company, Count: 65
# Label: Statue, Count: 1
# Label: Event, Count: 49
# Label: Subsection, Count: 7
# Label: Financial services group, Count: 1
# Label: Actor, Count: 1
# Label: Tv series, Count: 1
# Label: Club, Count: 10
# Label: Tournament, Count: 25
# Label: Sponsor, Count: 2
# Label: Golf tour, Count: 4
# Label: Golf club, Count: 5
# Label: Educational institution, Count: 3
# Label: Political position, Count: 2
# Label: Page, Count: 3
# Label: Community, Count: 1
# Label: Railroad, Count: 1
# Label: Political party, Count: 4
# Label: Electoral riding, Count: 1
# Label: School, Count: 15
# Label: Book, Count: 1
# Label: Country, Count: 16
# Label: Region, Count: 3
# Label: Service, Count: 29
# Label: Abbreviation, Count: 1
# Label: Stock exchange, Count: 2
# Label: Activity, Count: 2
# Label: Amount, Count: 2
# Label: Product, Count: 1
# Label: Shareholder, Count: 2
# Label: Central bank, Count: 2
# Label: Commercial bank, Count: 22
# Label: Foreign bank (commercial), Count: 19
# Label: Digital bank (conventional), Count: 2
# Label: Digital bank (islamic), Count: 1
# Label: Bank with marketing and representative offices, Count: 10
# Label: Investment bank, Count: 35
# Label: Islamic bank, Count: 18
# Label: Development financial institution, Count: 12
# Label: Bank negara malaysia, Count: 1
# Label: Gx bank berhad, Count: 1
# Label: Boost bank berhad, Count: 1
# Label: Aeon bank (m) berhad, Count: 1
# Label: An1142 national bank limited, Count: 1
# Label: The bank of tokyo-mitsubishi ufj limited, Count: 1
# Label: The bank of new york mellon limited, Count: 1
# Label: Credit suisse limited, Count: 1
# Label: Middle east investment bank ltd, Count: 1
# Label: Dbs bank limited, Count: 1
# Label: National australia bank limited, Count: 1
# Label: The royal bank of scotland limited, Count: 1
# Label: Wells fargo bank limited, Count: 1
# Label: Zamora trading limited, Count: 1
# Label: Affin hwang capital, Count: 1
# Label: Alliance investment bank berhad, Count: 1
# Label: Aminvestment bank berhad, Count: 1
# Label: Cimb investment bank berhad, Count: 1
# Label: Hong leong investment bank berhad, Count: 1
# Label: Public investment bank berhad, Count: 1
# Label: Rhb investment bank berhad, Count: 1
# Label: Kaf investment bank berhad, Count: 1
# Label: Kenanga investment bank berhad, Count: 1
# Label: Maybank investment bank, Count: 1
# Label: Midf investment bank berhad, Count: 1
# Label: Mimb investment bank berhad, Count: 1
# Label: Osk investment bank berhad, Count: 1
# Label: Ecm libra investment bank berhad, Count: 1
# Label: Affin islamic bank berhad, Count: 1
# Label: Al rajhi bank, Count: 1
# Label: Alkhair international islamic bank malaysia, Count: 1
# Label: Alliance islamic bank berhad, Count: 1
# Label: Ambank islamic berhad, Count: 1
# Label: Mbsb bank berhad, Count: 1
# Label: Asia offshore finance agency, Count: 1
# Label: Bank islam malaysia, Count: 1
# Label: Bank muamalat malaysia, Count: 1
# Label: Cimb islamic bank berhad, Count: 1
# Label: Hong leong islamic banking berhad, Count: 1
# Label: Hsbc amanah malaysia berhad, Count: 1
# Label: Kuwait finance house (malaysia) berhad, Count: 1
# Label: Maybank islamic berhad, Count: 1
# Label: Ocbc al-amin bank berhad, Count: 1
# Label: Public islamic bank berhad, Count: 1
# Label: Rhb islamic bank berhad, Count: 1
# Label: Agro bank malaysia, Count: 1
# Label: Bank rakyat, Count: 1
# Label: Bank simpanan nasional, Count: 1
# Label: Export-import bank of malaysia berhad (exim bank), Count: 1
# Label: Bank perusahaan kecil & sederhana berhad (sme bank berhad), Count: 1
# Label: Sabah development bank berhad (sdb), Count: 1
# Label: Sabah credit corporation (scc), Count: 1
# Label: Tabung haji, Count: 1
# Label: Credit guarantee corporation malaysia berhad (cgc), Count: 1
# Label: Malaysia debt ventures berhad, Count: 1
# Label: Malaysian industrial development finance berhad (midf), Count: 1
# Label: Bank pembangunan malaysia berhad (bpmb) (the development bank of malaysia), Count: 1
# Label: Radio station, Count: 1
# Label: Radio network, Count: 1
# Label: Year, Count: 6
# Label: Radio frequency, Count: 2
# Label: Language, Count: 5
# Label: University, Count: 5
# Label: Government agency, Count: 1
# Label: College, Count: 1
# Label: Fellowship, Count: 1
# Label: Ethnicity, Count: 1
# Label: Scandal, Count: 1
# Label: Regulation, Count: 1
# Label: Circular, Count: 1
# Label: Mobile app, Count: 1
# Label: Station, Count: 2
# Label: Function, Count: 7
# Label: Group, Count: 1
# Label: Title, Count: 1
# Label: Championship, Count: 1
# Label: Golf championship, Count: 2
# Label: Ranking, Count: 1
# Label: Golf tournament, Count: 19
# Label: Award, Count: 1
# Label: Team, Count: 2
# Label: Sports team, Count: 1
# Label: Membership, Count: 1
# Label: Golfer, Count: 6
# Label: Record, Count: 1
# Label: Golf course, Count: 2
# Label: Month, Count: 5
# Label: Card, Count: 1
# Label: Golf program, Count: 1
# Label: Tennis player, Count: 1
# Label: Architect, Count: 1
# Label: Hospital, Count: 2
# Label: Sports league, Count: 1
# Label: League, Count: 4
# Label: State-owned bank, Count: 6
# Label: Foreign bank, Count: 15
# Label: Representative office, Count: 31
# Label: Position, Count: 1
# Label: Business segment, Count: 1
# Label: Customer segment, Count: 2
# Label: Article, Count: 1
# Label: Holiday, Count: 12
# Label: Joint venture, Count: 1
# Label: List, Count: 2
# Label: Bank holiday, Count: 1
# Label: List of current holidays, Count: 1
# Label: Notes, Count: 1
# Label: See also, Count: 1
# Label: References, Count: 1
# Label: External links, Count: 1
# Label: Central_bank, Count: 1
# Label: Bank_category, Count: 7
# Label: Information, Count: 1
# Label: Bank branch, Count: 3
# Inverse multiple inheritance: 0
# Subclass property acquisition: 0
# Subclass property instantiation: 0
